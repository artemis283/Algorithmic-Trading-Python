# %%
from smabacktest import SMABacktester

# %%
tester = SMABacktester("AAPL", 1, 200, "2000-01-01", "2023-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (273.181461, -65.240455)

# %%
tester.plot_results()
