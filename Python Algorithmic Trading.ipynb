# %%
# importing the necesary modules

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Storing the apple stock in a variable
Apple = yf.download("AAPL", start = "2010-01-01", end = "2023-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.496295
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.507526
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.404015
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.392175
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.434674
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.477127
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.652435
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.674026
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.233658
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.552719
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker=["SPY", "AAPL", "KO"]

# %%
# storing the three stocks in a variable
stocks = yf.download(ticker, start = "2010-01-01", end = "2023-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.496294  18.793236   87.791794    7.643214  28.520000
# 2010-01-05    6.507525  18.565897   88.024178    7.656429  28.174999
# 2010-01-06    6.404015  18.559313   88.086121    7.534643  28.165001
# 2010-01-07    6.392177  18.513184   88.457993    7.520714  28.094999
# 2010-01-08    6.434673  18.170534   88.752357    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2022-12-23  131.477127  62.855492  380.042480  131.860001  63.820000
# 2022-12-27  129.652435  63.239597  378.543793  130.029999  64.209999
# 2022-12-28  125.674026  62.609272  373.839264  126.040001  63.570000
# 2022-12-29  129.233658  62.983532  380.568512  129.610001  63.950001
# 2022-12-30  129.552719  62.648666  379.566040  129.929993  63.610001
#
# ...

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.496294  18.793236  87.791794  7.643214  28.520000  113.330002
# 2010-01-05  6.507525  18.565897  88.024178  7.656429  28.174999  113.629997
# 2010-01-06  6.404015  18.559313  88.086121  7.534643  28.165001  113.709999
# 2010-01-07  6.392177  18.513184  88.457993  7.520714  28.094999  114.190002
# 2010-01-08  6.434673  18.170534  88.752357  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3272 entries, 2010-01-04 to 2022-12-30
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3272 non-null   float64
#  1   (Adj Close, KO)    3272 non-null   float64
#  2   (Adj Close, SPY)   3272 non-null   float64
#  3   (Close, AAPL)      3272 non-null   float64
#  4   (Close, KO)        3272 non-null   float64
#  5   (Close, SPY)       3272 non-null   float64
#  6   (High, AAPL)       3272 non-null   float64
#  7   (High, KO)         3272 non-null   float64
#  8   (High, SPY)        3272 non-null   float64
#  9   (Low, AAPL)        3272 non-null   float64
#  10  (Low, KO)          3272 non-null   float64
#  11  (Low, SPY)         3272 non-null   float64
#  12  (Open, AAPL)       3272 non-null   float64
#  13  (Open, KO)         3272 non-null   float64
#  14  (Open, SPY)        3272 non-null   float64
# ...

# %%
# Saving the stocks to a csv file
stocks.to_csv("StocksYT.csv")

# %%
stocks = pd.read_csv("StocksYT.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1        Adj Close.2  \
# 0            NaN                AAPL                  KO                SPY
# 1           Date                 NaN                 NaN                NaN
# 2     2010-01-04   6.496293544769287  18.793235778808594  87.79179382324219
# 3     2010-01-05  6.5075249671936035   18.56589698791504  88.02417755126953
# 4     2010-01-06   6.404015064239502   18.55931282043457  88.08612060546875
# ...          ...                 ...                 ...                ...
# 3269  2022-12-23   131.4771270751953  62.855491638183594    380.04248046875
# 3270  2022-12-27  129.65243530273438   63.23959732055664  378.5437927246094
# 3271  2022-12-28  125.67402648925781   62.60927200317383  373.8392639160156
# 3272  2022-12-29  129.23365783691406    62.9835319519043  380.5685119628906
# 3273  2022-12-30  129.55271911621094   62.64866638183594  379.5660400390625
#
# ...

# %%
stocks = pd.read_csv("StocksYT.csv", header = [0,1])
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.496294  18.793236   87.791794    7.643214
# 2            2010-01-05    6.507525  18.565897   88.024178    7.656429
# 3            2010-01-06    6.404015  18.559313   88.086121    7.534643
# 4            2010-01-07    6.392177  18.513184   88.457993    7.520714
# ...                 ...         ...        ...         ...         ...
# 3268         2022-12-23  131.477127  62.855492  380.042480  131.860001
# 3269         2022-12-27  129.652435  63.239597  378.543793  130.029999
# 3270         2022-12-28  125.674026  62.609272  373.839264  126.040001
# 3271         2022-12-29  129.233658  62.983532  380.568512  129.610001
# 3272         2022-12-30  129.552719  62.648666  379.566040  129.929993
#
# ...

# %%
stocks = pd.read_csv("StocksYT.csv", header = [0,1], index_col=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.496294  18.793236   87.791794    7.643214  28.520000
# 2010-01-05    6.507525  18.565897   88.024178    7.656429  28.174999
# 2010-01-06    6.404015  18.559313   88.086121    7.534643  28.165001
# 2010-01-07    6.392177  18.513184   88.457993    7.520714  28.094999
# 2010-01-08    6.434673  18.170534   88.752357    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2022-12-23  131.477127  62.855492  380.042480  131.860001  63.820000
# 2022-12-27  129.652435  63.239597  378.543793  130.029999  64.209999
# 2022-12-28  125.674026  62.609272  373.839264  126.040001  63.570000
# 2022-12-29  129.233658  62.983532  380.568512  129.610001  63.950001
# 2022-12-30  129.552719  62.648666  379.566040  129.929993  63.610001
#
# ...

# %%
stocks = pd.read_csv("StocksYT.csv", header = [0,1], index_col=[0], parse_dates=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.496294  18.793236   87.791794    7.643214  28.520000
# 2010-01-05    6.507525  18.565897   88.024178    7.656429  28.174999
# 2010-01-06    6.404015  18.559313   88.086121    7.534643  28.165001
# 2010-01-07    6.392177  18.513184   88.457993    7.520714  28.094999
# 2010-01-08    6.434673  18.170534   88.752357    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2022-12-23  131.477127  62.855492  380.042480  131.860001  63.820000
# 2022-12-27  129.652435  63.239597  378.543793  130.029999  64.209999
# 2022-12-28  125.674026  62.609272  373.839264  126.040001  63.570000
# 2022-12-29  129.233658  62.983532  380.568512  129.610001  63.950001
# 2022-12-30  129.552719  62.648666  379.566040  129.929993  63.610001
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# Converting MultiIndex to one tuple 

stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.496294        18.793236         87.791794
# 2010-01-05           6.507525        18.565897         88.024178
# 2010-01-06           6.404015        18.559313         88.086121
# 2010-01-07           6.392177        18.513184         88.457993
# 2010-01-08           6.434673        18.170534         88.752357
# ...                       ...              ...               ...
# 2022-12-23         131.477127        62.855492        380.042480
# 2022-12-27         129.652435        63.239597        378.543793
# 2022-12-28         125.674026        62.609272        373.839264
# 2022-12-29         129.233658        62.983532        380.568512
# 2022-12-30         129.552719        62.648666        379.566040
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
# Converting list of tuples back to multi index 
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  3272.000000  3272.000000  3272.000000  3272.000000  3272.000000
# mean     49.326076    36.195943   217.880214    51.321186    43.864995
# std      47.685114    11.358195   104.089537    47.357062     8.837265
# min       5.829697    16.635139    79.874092     6.858929    25.014999
# 25%      16.578033    28.006497   129.203823    18.967589    38.520000
# 50%      27.306855    34.114922   185.754868    29.815000    42.730000
# 75%      54.793891    43.468523   274.330399    56.777499    48.882499
# max     180.434280    63.820396   466.563324   182.009995    66.209999
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  3272.000000  3272.000000  3272.000000  3272.000000  3272.000000
# ...

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2022-12-23  131.860001  63.820000  382.910004
# 2022-12-27  130.029999  64.209999  381.399994
# 2022-12-28  126.040001  63.570000  376.660004
# 2022-12-29  129.610001  63.950001  383.440002
# 2022-12-30  129.929993  63.610001  382.429993
#
# [3272 rows x 3 columns]

# %%
# Plotting the Apple, Coca Cola and Spy stocks
# %matplotlib inline
plt.style.use("seaborn")
close.plot(figsize=(15,8), fontsize = 12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0] # First value and first row in 'Close' table
# Out:
# 7.643214225769043

# %%
close.AAPL
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2022-12-23    131.860001
# 2022-12-27    130.029999
# 2022-12-28    126.040001
# 2022-12-29    129.610001
# 2022-12-30    129.929993
# Name: AAPL, Length: 3272, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]) # dividing values to normalise the data
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2022-12-23    17.251904
# 2022-12-27    17.012476
# 2022-12-28    16.490445
# 2022-12-29    16.957526
# 2022-12-30    16.999392
# Name: AAPL, Length: 3272, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100) # multiplying values by 100
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2022-12-23    1725.190433
# 2022-12-27    1701.247603
# 2022-12-28    1649.044462
# 2022-12-29    1695.752556
# 2022-12-30    1699.939173
# Name: AAPL, Length: 3272, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
normclose = close.div(close.iloc[0]).mul(100) # normalising all the data and multiplying it by 100

# %%
normclose
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2022-12-23  1725.190433  223.772786  337.871700
# 2022-12-27  1701.247603  225.140246  336.539299
# 2022-12-28  1649.044462  222.896209  332.356832
# 2022-12-29  1695.752556  224.228611  338.339360
# 2022-12-30  1699.939173  223.036464  337.448148
#
# [3272 rows x 3 columns]

# %%
# Plotting the normalised data to show that Apple has outperformed the other stocks
# %matplotlib inline
plt.style.use("seaborn")
normclose.plot(figsize=(15,8), fontsize = 12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.copy().to_frame() # Converting the close data to a dataframe
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2022-12-23  131.860001
# 2022-12-27  130.029999
# 2022-12-28  126.040001
# 2022-12-29  129.610001
# 2022-12-30  129.929993
#
# [3272 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods = 1) # Shifts index by desired number of periods
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2022-12-23  131.860001  132.229996
# 2022-12-27  130.029999  131.860001
# 2022-12-28  126.040001  130.029999
# 2022-12-29  129.610001  126.040001
# 2022-12-30  129.929993  129.610001
#
# [3272 rows x 2 columns]

# %%
# The lag1 column allows the daily percentage change to be calculated
# First the difference between the days is calculated

aapl["Diff"]=aapl.AAPL.sub(aapl.lag1)
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995
# 2022-12-27  130.029999  131.860001 -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000
# 2022-12-30  129.929993  129.610001  0.319992
#
# [3272 rows x 3 columns]

# %%
# Next the percentage change is calculated
aapl["% Change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995 -0.279812
# 2022-12-27  130.029999  131.860001 -1.830002 -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998 -3.068521
# 2022-12-29  129.610001  126.040001  3.570000  2.832434
# 2022-12-30  129.929993  129.610001  0.319992  0.246888
#
# [3272 rows x 4 columns]

# %%
# Using the diff function to show it gives the same result as the sub() function
aapl["Diff2"]=aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995 -0.279812 -0.369995
# 2022-12-27  130.029999  131.860001 -1.830002 -1.387837 -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998 -3.068521 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000  2.832434  3.570000
# 2022-12-30  129.929993  129.610001  0.319992  0.246888  0.319992
#
# [3272 rows x 5 columns]

# %%
# Using the percentage change function
aapl["% Change 2"] = aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2022-12-23  131.860001  132.229996 -0.369995 -0.279812 -0.369995   -0.279812
# 2022-12-27  130.029999  131.860001 -1.830002 -1.387837 -1.830002   -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998 -3.068521 -3.989998   -3.068521
# 2022-12-29  129.610001  126.040001  3.570000  2.832434  3.570000    2.832434
# 2022-12-30  129.929993  129.610001  0.319992  0.246888  0.319992    0.246888
#
# [3272 rows x 6 columns]

# %%
# Deleting the unecessary columns
del aapl["Diff"]
del aapl["lag1"]
del aapl["% Change"]
aapl
# Out:
#                   AAPL     Diff2  % Change 2
# Date
# 2010-01-04    7.643214       NaN         NaN
# 2010-01-05    7.656429  0.013215    0.172893
# 2010-01-06    7.534643 -0.121786   -1.590632
# 2010-01-07    7.520714 -0.013929   -0.184871
# 2010-01-08    7.570714  0.050000    0.664833
# ...                ...       ...         ...
# 2022-12-23  131.860001 -0.369995   -0.279812
# 2022-12-27  130.029999 -1.830002   -1.387837
# 2022-12-28  126.040001 -3.989998   -3.068521
# 2022-12-29  129.610001  3.570000    2.832434
# 2022-12-30  129.929993  0.319992    0.246888
#
# [3272 rows x 3 columns]

# %%
# Renaming the "% Change 2" column
aapl.rename(columns = {"% Change 2":"Change"}, inplace = True)
aapl
# Out:
#                   AAPL     Diff2    Change
# Date
# 2010-01-04    7.643214       NaN       NaN
# 2010-01-05    7.656429  0.013215  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871
# 2010-01-08    7.570714  0.050000  0.664833
# ...                ...       ...       ...
# 2022-12-23  131.860001 -0.369995 -0.279812
# 2022-12-27  130.029999 -1.830002 -1.387837
# 2022-12-28  126.040001 -3.989998 -3.068521
# 2022-12-29  129.610001  3.570000  2.832434
# 2022-12-30  129.929993  0.319992  0.246888
#
# [3272 rows x 3 columns]

# %%
# Resampling the daily data to monthly data
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2022-08-31    157.220001
# 2022-09-30    138.199997
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-31    129.929993
# Freq: M, Name: AAPL, Length: 156, dtype: float64

# %%
# Converting to the last business day of the month
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2022-08-31    -3.255180
# 2022-09-30   -12.097700
# 2022-10-31    10.955137
# 2022-11-30    -3.462891
# 2022-12-30   -12.227255
# Freq: BM, Name: AAPL, Length: 156, dtype: float64

# %%
del aapl["Change"]
aapl
# Out:
#                   AAPL     Diff2
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.013215
# 2010-01-06    7.534643 -0.121786
# 2010-01-07    7.520714 -0.013929
# 2010-01-08    7.570714  0.050000
# ...                ...       ...
# 2022-12-23  131.860001 -0.369995
# 2022-12-27  130.029999 -1.830002
# 2022-12-28  126.040001 -3.989998
# 2022-12-29  129.610001  3.570000
# 2022-12-30  129.929993  0.319992
#
# [3272 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()
ret.info
# Out:
# <bound method DataFrame.info of                 AAPL      Diff2
# Date
# 2010-01-06 -0.015906 -10.216000
# 2010-01-07 -0.001849  -0.885624
# 2010-01-08  0.006648  -4.589552
# 2010-01-11 -0.008821  -2.335692
# 2010-01-12 -0.011375   0.278106
# ...              ...        ...
# 2022-12-23 -0.002798  -0.885095
# 2022-12-27 -0.013878   3.946016
# 2022-12-28 -0.030685   1.180325
# 2022-12-29  0.028324  -1.894737
# 2022-12-30  0.002469  -0.910366
#
# [3270 rows x 2 columns]>

# %%
# Plotting a histogram to show the distribution of the percentage difference
ret.plot(kind="hist", figsize = (12,8), bins = 100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/by/n7sp3j194cj_fczhvltncp2r0000gn/T/ipykernel_13860/3925097906.py in <module>
#       1 # Plotting a histogram to show the distribution of the percentage difference
# ----> 2 ret.plot(kind="hist", figsize = (12,8), bins = 100)
#       3 plt.show()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
# ...

# %%
# Calculating the mean
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# AAPL     0.00103
# Diff2        NaN
# dtype: float64

# %%
# Calculating the variance
var_daily = ret.var()
var_daily
# Out:
# AAPL     0.000328
# Diff2         NaN
# dtype: float64

# %%
# Calculating the standard deviation, the std() funciton could also be used
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# AAPL     0.018102
# Diff2         NaN
# dtype: float64

# %%
# Calculating the annual mean return from multiplying the daily mean return by ...
# the total number of working days in a year
annual_mean_ret = daily_mean_ret * 252
annual_mean_ret
# Out:
# AAPL     0.259609
# Diff2         NaN
# dtype: float64

# %%
# Calculating the annual variance return
annual_var_ret = var_daily * 252
annual_var_ret
# Out:
# AAPL     0.082576
# Diff2         NaN
# dtype: float64

# %%
# Calculating the annual standard deviation return
annual_std_return = np.sqrt(annual_var_ret)
annual_std_return
# Out:
# AAPL     0.287361
# Diff2         NaN
# dtype: float64

# %%
# Importing the data from other stocks so that the values can be compared
ticker=["SPY", "AAPL", "KO", "IBM", "DIS", "MSFT"]
stocks = yf.download(ticker, start = "2010-01-01", end = "2023-01-01")
stocks
# Out:
# [*********************100%***********************]  6 of 6 completed
#              Adj Close                                                \
#                   AAPL        DIS         IBM         KO        MSFT
# Date
# 2010-01-04    6.496294  27.933918   79.247452  18.793242   23.572369
# 2010-01-05    6.507527  27.864241   78.290146  18.565901   23.579987
# 2010-01-06    6.404016  27.716166   77.781555  18.559311   23.435280
# 2010-01-07    6.392175  27.724873   77.512337  18.513184   23.191553
# 2010-01-08    6.434674  27.768423   78.290146  18.170530   23.351494
# ...                ...        ...         ...        ...         ...
# 2022-12-23  131.477127  88.010002  138.048813  62.855492  237.614105
# 2022-12-27  129.652435  86.370003  138.799240  63.239597  235.852386
# 2022-12-28  125.674026  84.169998  136.460266  62.609272  233.433731
# 2022-12-29  129.233658  87.180000  137.473816  62.983532  239.883438
# ...

# %%
# Saving the closing data in a variable
close = stocks.loc[:,"Close"].copy()
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#                    AAPL         DIS         IBM          KO        MSFT  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172893   99.750546   98.792000   98.790318  100.032305
# 2010-01-06    98.579511   99.220455   98.150247   98.755261   99.418416
# 2010-01-07    98.397266   99.251638   97.810499   98.509814   98.384491
# 2010-01-08    99.051443   99.407544   98.792000   96.686537   99.063002
# ...                 ...         ...         ...         ...         ...
# 2022-12-23  1725.190433  274.430942  111.865532  223.772786  771.340840
# 2022-12-27  1701.247603  269.317130  112.473629  225.140246  765.621974
# 2022-12-28  1649.044462  262.457122  110.578277  222.896209  757.770575
# 2022-12-29  1695.752556  271.842847  111.399593  224.228611  778.707556
# 2022-12-30  1699.939173  270.907384  111.265340  223.036464  774.862686
#
#                    SPY
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.264710
# ...

# %%
normclose.plot(figsize = (15, 8), fontsize = 12)
plt.legend(fontsize=12)
plt.show()

# %%
# Calculating the daily percentage change
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  3271.0  0.001030  0.018099 -0.128647 -0.007652  0.000865  0.010640
# DIS   3271.0  0.000440  0.016435 -0.131632 -0.006798  0.000427  0.008040
# IBM   3271.0  0.000135  0.014255 -0.128507 -0.006398  0.000326  0.007037
# KO    3271.0  0.000307  0.011097 -0.096725 -0.004747  0.000488  0.005900
# MSFT  3271.0  0.000760  0.016392 -0.147390 -0.007240  0.000534  0.009028
# SPY   3271.0  0.000434  0.011132 -0.109424 -0.003830  0.000595  0.005689
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary = ret.describe().T.loc[:, ["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001030  0.018099
# DIS   0.000440  0.016435
# IBM   0.000135  0.014255
# KO    0.000307  0.011097
# MSFT  0.000760  0.016392
# SPY   0.000434  0.011132

# %%
# Calculating the annual mean and standard deviation
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.259663  0.287317
# DIS   0.110785  0.260902
# IBM   0.033968  0.226295
# KO    0.077394  0.176152
# MSFT  0.191645  0.260214
# SPY   0.109393  0.176719

# %%
# Plotting the standard deviation against the mean
summary.plot.scatter(x="std", y ="mean", figsize=(12,8), s=50, fontsize=15)

for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i,"mean"] + 0.002), size = 15)
    
plt.xlabel("Annual risk(std)", fontsize = 15)
plt.ylabel("Annual return", fontsize = 15)
plt.title("Risk/return", fontsize=25)
plt.show()

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23 -0.002798  0.015461  0.005466  0.007578  0.002267  0.005752
# 2022-12-27 -0.013878 -0.018634  0.005436  0.006111 -0.007414 -0.003944
# 2022-12-28 -0.030685 -0.025472 -0.016852 -0.009967 -0.010255 -0.012428
# 2022-12-29  0.028324  0.035761  0.007427  0.005978  0.027630  0.018000
# 2022-12-30  0.002469 -0.003441 -0.001205 -0.005317 -0.004938 -0.002634
#
# [3271 rows x 6 columns]

# %%
# Covariation function
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000328  0.000126  0.000107  0.000071  0.000177  0.000139
# DIS   0.000126  0.000270  0.000106  0.000084  0.000131  0.000128
# IBM   0.000107  0.000106  0.000203  0.000077  0.000114  0.000104
# KO    0.000071  0.000084  0.000077  0.000123  0.000078  0.000077
# MSFT  0.000177  0.000131  0.000114  0.000078  0.000269  0.000139
# SPY   0.000139  0.000128  0.000104  0.000077  0.000139  0.000124

# %%
# Correlation function
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.424060  0.415156  0.352489  0.595650  0.689343
# DIS   0.424060  1.000000  0.450761  0.461784  0.486882  0.700196
# IBM   0.415156  0.450761  1.000000  0.486299  0.485986  0.657488
# KO    0.352489  0.461784  0.486299  1.000000  0.426982  0.623916
# MSFT  0.595650  0.486882  0.485986  0.426982  1.000000  0.762329
# SPY   0.689343  0.700196  0.657488  0.623916  0.762329  1.000000

# %%
import seaborn as sns

# %%
# Correlation heatmap betweens stocks
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds", annot=True, annot_kws={"size":15}, vmax=0.6)
plt.show()

# %% [markdown]
# ## Challenge 1

# %% [markdown]
# ## Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016, 2017, 2018], data=[100, 50, 95], columns = ["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
# Simple returns mean
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
# Mean returns are misleading so the log return will be calculated
log_returns = np.log(df/df.shift(1)).dropna()
log_returns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
log_returns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(log_returns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
spy = SPY.Close.to_frame()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-07-10  439.660004
# 2023-07-11  442.459991
# 2023-07-12  446.019989
# 2023-07-13  449.559998
# 2023-07-14  449.279999
#
# [7669 rows x 1 columns]

# %%
# Plotting the SPY closing data
spy.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc="upper left", fontsize = 15)
plt.show()

# %%
# Calculting the rolling window calculation with a window of 10 days
spy_roll = spy.rolling(window=10)
spy_roll = spy_roll.mean().dropna()
spy_roll
# Out:
#                  Close
# Date
# 1993-02-11   44.659375
# 1993-02-12   44.725000
# 1993-02-16   44.646875
# 1993-02-17   44.556250
# 1993-02-18   44.415625
# ...                ...
# 2023-07-10  439.018002
# 2023-07-11  440.120001
# 2023-07-12  441.104999
# 2023-07-13  442.421997
# 2023-07-14  443.538998
#
# [7660 rows x 1 columns]

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-07-10  439.104996
# 2023-07-11  439.660004
# 2023-07-12  441.059998
# 2023-07-13  442.794998
# 2023-07-14  443.205002
#
# [7669 rows x 1 columns]

# %%
# Calculating the maximum value from the last 10 days
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-07-10  443.790009
# 2023-07-11  443.790009
# 2023-07-12  446.019989
# 2023-07-13  449.559998
# 2023-07-14  449.559998
#
# [7669 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
# Creating a new column for the moving average
spy["SMA50"]=spy.rolling(window=50, min_periods=50).mean()
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# ...

# %%
spy
# Out:
#                  Close     SMA50
# Date
# 1993-01-29   43.937500       NaN
# 1993-02-01   44.250000       NaN
# 1993-02-02   44.343750       NaN
# 1993-02-03   44.812500       NaN
# 1993-02-04   45.000000       NaN
# ...                ...       ...
# 2023-07-10  439.660004  424.9178
# 2023-07-11  442.459991  425.5188
# 2023-07-12  446.019989  426.1206
# 2023-07-13  449.559998  426.8016
# 2023-07-14  449.279999  427.5704
#
# [7669 rows x 2 columns]

# %%
# Plotting a graph showing the SMA and prices
spy.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc="upper left", fontsize = 15)
plt.show()

# %%
# Plotting the graph for the 200 day moving average
spy["SMA200"]=spy.Close.rolling(window=200, min_periods=50).mean()
spy.head(52)

spy.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc="upper left", fontsize = 15)
plt.show()

# %%
# Calculating the ema
spy["EMA100"]=spy.Close.ewm(span=100, min_periods=100).mean()
spy
# Out:
#                  Close     SMA50     SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500       NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000       NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750       NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500       NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000       NaN        NaN         NaN   Thursday        1
# ...                ...       ...        ...         ...        ...      ...
# 2023-07-10  439.660004  424.9178  400.56890  417.928881     Monday        3
# 2023-07-11  442.459991  425.5188  400.89425  418.414645    Tuesday        3
# 2023-07-12  446.019989  426.1206  401.25325  418.961286  Wednesday        3
# 2023-07-13  449.559998  426.8016  401.66130  419.567201   Thursday        3
# 2023-07-14  449.279999  427.5704  402.08615  420.155573     Friday        3
#
# [7669 rows x 6 columns]

# %%
spy.plot(figsize = (12, 8), fontsize = 15)
plt.legend(loc="upper left", fontsize = 15)
plt.show()

# %%
spy["Day"] = spy.index.day_name()
spy["Quarter"] = spy.index.quarter
spy
# Out:
#                  Close     SMA50     SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500       NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000       NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750       NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500       NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000       NaN        NaN         NaN   Thursday        1
# ...                ...       ...        ...         ...        ...      ...
# 2023-07-10  439.660004  424.9178  400.56890  417.928881     Monday        3
# 2023-07-11  442.459991  425.5188  400.89425  418.414645    Tuesday        3
# 2023-07-12  446.019989  426.1206  401.25325  418.961286  Wednesday        3
# 2023-07-13  449.559998  426.8016  401.66130  419.567201   Thursday        3
# 2023-07-14  449.279999  427.5704  402.08615  420.155573     Friday        3
#
# [7669 rows x 6 columns]

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
all_days = pd.date_range(start="2010-12-31", end="2023-01-01", freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2022-12-23', '2022-12-24', '2022-12-25', '2022-12-26',
#                '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30',
#                '2022-12-31', '2023-01-01'],
#               dtype='datetime64[ns]', length=4385, freq='D')

# %%
spy
# Out:
#                  Close     SMA50     SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500       NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000       NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750       NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500       NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000       NaN        NaN         NaN   Thursday        1
# ...                ...       ...        ...         ...        ...      ...
# 2023-07-10  439.660004  424.9178  400.56890  417.928881     Monday        3
# 2023-07-11  442.459991  425.5188  400.89425  418.414645    Tuesday        3
# 2023-07-12  446.019989  426.1206  401.25325  418.961286  Wednesday        3
# 2023-07-13  449.559998  426.8016  401.66130  419.567201   Thursday        3
# 2023-07-14  449.279999  427.5704  402.08615  420.155573     Friday        3
#
# [7669 rows x 6 columns]

# %%
del spy["SMA200"]
del spy["EMA100"]
del spy["Day"]
del spy["Quarter"]
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-07-10  439.660004
# 2023-07-11  442.459991
# 2023-07-12  446.019989
# 2023-07-13  449.559998
# 2023-07-14  449.279999
#
# [7669 rows x 1 columns]

# %%
# Reindexing the days
spy=spy.reindex(all_days)
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2022-12-28  376.660004
# 2022-12-29  383.440002
# 2022-12-30  382.429993
# 2022-12-31         NaN
# 2023-01-01         NaN
#
# [4385 rows x 1 columns]

# %%
# Forward filling the 'NaN' values
spy.fillna(method="ffill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2022-12-28  376.660004
# 2022-12-29  383.440002
# 2022-12-30  382.429993
# 2022-12-31  382.429993
# 2023-01-01  382.429993
#
# [4385 rows x 1 columns]

# %%
# Changing the data to weekly data
SPY = yf.download("SPY", interval="1wk")
SPY
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   25.029371
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.616835
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.403212
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.815739
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.296402
# ...                ...         ...         ...         ...         ...
# 2023-06-12  430.920013  443.899994  430.170013  439.459991  437.833618
# 2023-06-19  437.450012  438.369995  432.470001  433.209991  433.209991
# 2023-06-26  432.619995  444.299988  431.190002  443.279999  443.279999
# 2023-07-03  442.920013  444.079987  437.059998  438.549988  438.549988
# 2023-07-10  438.179993  451.359985  437.589996  449.279999  449.279999
#
#                Volume
# Date
# ...

# %% [markdown]
# ## Clumulative Returns, Drawdowns etc..

# %%
apple = yf.download("AAPL")
apple = apple.Close.to_frame()
apple
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-07-10  188.610001
# 2023-07-11  188.080002
# 2023-07-12  189.770004
# 2023-07-13  190.539993
# 2023-07-14  190.690002
#
# [10736 rows x 1 columns]

# %%
# Adding a daily returns column to the table
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-07-10  188.610001  -0.010915
# 2023-07-11  188.080002  -0.002814
# 2023-07-12  189.770004   0.008945
# 2023-07-13  190.539993   0.004049
# 2023-07-14  190.690002   0.000787
#
# [10735 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-07-10  188.610001  -0.010915
# 2023-07-11  188.080002  -0.002814
# 2023-07-12  189.770004   0.008945
# 2023-07-13  190.539993   0.004049
# 2023-07-14  190.690002   0.000787
#
# [10735 rows x 2 columns]

# %%
# Calculating the sum of the returns
apple.d_returns.sum()
# Out:
# 7.303659095169311

# %%
# Showing what $1 invested in 1980 would be worth now (July 2023)
np.exp(apple.d_returns.sum())
# Out:
# 1485.7264078479768

# %%
# Calculating the cumulative returns and adding a column to the table
apple["cummreturns"] = apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-07-10  188.610001  -0.010915  1469.520453
# 2023-07-11  188.080002  -0.002814  1465.391064
# 2023-07-12  189.770004   0.008945  1478.558410
# 2023-07-13  190.539993   0.004049  1484.557639
# 2023-07-14  190.690002   0.000787  1485.726408
#
# [10735 rows x 3 columns]

# %%
# Plotting the Apple buy and hold cumulative returns
apple.cummreturns.plot(figsize = (12,8), title = "Apple buy and hold", fontsize = 12)
plt.show()

# %%
# Calculating the annual average return
annual_mean = apple.d_returns.mean() * 252
print(f"Annual average return: {annual_mean}")
# Out:
# Annual average return: 0.17145059077621563

# %%
# Calculating the standard deviation
standard_deviation = apple.d_returns.std()*np.sqrt(252)
print(f"Annual average return: {standard_deviation}")
# Out:
# Annual average return: 0.4535738093053663

# %%
# calculating drawdowns
apple["cummax"]=apple.cummreturns.cummax()
apple

del apple["cummmax"]

# %%
# Plotting the apple buy and hold with cummulative max
apple[["cummreturns", "cummax"]].plot(figsize = (12,8), title = "Apple buy and hold with cummax", fontsize = 12)
plt.show()

# %%
apple["drawdown"] = apple["cummax"]-apple["cummreturns"]
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2023-07-10  188.610001  -0.010915  1469.520453  1511.281921  41.761468
# 2023-07-11  188.080002  -0.002814  1465.391064  1511.281921  45.890857
# 2023-07-12  189.770004   0.008945  1478.558410  1511.281921  32.723511
# 2023-07-13  190.539993   0.004049  1484.557639  1511.281921  26.724282
# 2023-07-14  190.690002   0.000787  1485.726408  1511.281921  25.555513
#
# [10735 rows x 5 columns]

# %%
# Calculating the maximum drawdown
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
# Finding the date of the maximum drawdown
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2023-01-05')]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
# Calculating percentage drawdown
apple["drawdown%"]=(apple["cummax"]-apple["cummreturns"])/apple["cummax"]
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2023-07-10  188.610001  -0.010915  1469.520453  1511.281921  41.761468
# 2023-07-11  188.080002  -0.002814  1465.391064  1511.281921  45.890857
# 2023-07-12  189.770004   0.008945  1478.558410  1511.281921  32.723511
# 2023-07-13  190.539993   0.004049  1484.557639  1511.281921  26.724282
# 2023-07-14  190.690002   0.000787  1485.726408  1511.281921  25.555513
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# ...

# %%
# Calculating the maximum percentage drawdown
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cummreturns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# ## Creating the first strategy - SMA strategy

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]
data
# Out:
# Date
# 1991-01-02      0.388393
# 1991-01-03      0.383929
# 1991-01-04      0.386161
# 1991-01-07      0.386161
# 1991-01-08      0.386161
#                  ...
# 2023-07-10    188.610001
# 2023-07-11    188.080002
# 2023-07-12    189.770004
# 2023-07-13    190.539993
# 2023-07-14    190.690002
# Name: Close, Length: 8195, dtype: float64

# %%
data = data.to_frame()
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-07-10  188.610001
# 2023-07-11  188.080002
# 2023-07-12  189.770004
# 2023-07-13  190.539993
# 2023-07-14  190.690002
#
# [8195 rows x 1 columns]

# %%
# Creating two moving averages of 50 and 100 days
sma_s = 50
sma_l = 100

# %%
# Adding the columns to the table
data["sma_s"] = data.Close.rolling(sma_s).mean()
data["sma_l"] = data.Close.rolling(sma_l).mean()
data
# Out:
#                  Close     sma_s     sma_l
# Date
# 1991-01-02    0.388393       NaN       NaN
# 1991-01-03    0.383929       NaN       NaN
# 1991-01-04    0.386161       NaN       NaN
# 1991-01-07    0.386161       NaN       NaN
# 1991-01-08    0.386161       NaN       NaN
# ...                ...       ...       ...
# 2023-07-10  188.610001  179.2126  168.2622
# 2023-07-11  188.080002  179.6060  168.6110
# 2023-07-12  189.770004  180.0078  168.9554
# 2023-07-13  190.539993  180.4268  169.3237
# 2023-07-14  190.690002  180.8698  169.7051
#
# [8195 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title = "Apple - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
# Out:
# <AxesSubplot:title={'center':'Apple - SMA50 | SMA100'}, xlabel='Date'>

# %%
# Plotting the data for 2016 only
data.loc["2016"].plot(figsize=(12,8), title = "Apple - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
# Out:
# <AxesSubplot:title={'center':'Apple - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-07-10  188.610001  179.212600  168.262200
# 2023-07-11  188.080002  179.606000  168.611000
# 2023-07-12  189.770004  180.007800  168.955400
# 2023-07-13  190.539993  180.426800  169.323700
# 2023-07-14  190.690002  180.869800  169.705100
#
# [8096 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"], 1, -1)
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-07-10  188.610001  179.212600  168.262200         1
# 2023-07-11  188.080002  179.606000  168.611000         1
# 2023-07-12  189.770004  180.007800  168.955400         1
# 2023-07-13  190.539993  180.426800  169.323700         1
# 2023-07-14  190.690002  180.869800  169.705100         1
#
# [8096 rows x 4 columns]

# %%
data.loc["2016", ["sma_s", "sma_l", "position"]].plot(figsize=(12,8), title = "Apple - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12, secondary_y = "position")
# Out:
# <AxesSubplot:title={'center':'Apple - SMA50 | SMA100'}, xlabel='Date'>

# %%
# Calculating the buy and hold returns
data["returnsb&h"] = np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# ...                ...         ...         ...       ...         ...
# 2023-07-10  188.610001  179.212600  168.262200         1   -0.010915
# 2023-07-11  188.080002  179.606000  168.611000         1   -0.002814
# 2023-07-12  189.770004  180.007800  168.955400         1    0.008945
# 2023-07-13  190.539993  180.426800  169.323700         1    0.004049
# 2023-07-14  190.690002  180.869800  169.705100         1    0.000787
#
# [8096 rows x 5 columns]

# %%
data["stratergy"] = data["returnsb&h"]*data.position.shift(1)
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# ...                ...         ...         ...       ...         ...
# 2023-07-10  188.610001  179.212600  168.262200         1   -0.010915
# 2023-07-11  188.080002  179.606000  168.611000         1   -0.002814
# 2023-07-12  189.770004  180.007800  168.955400         1    0.008945
# 2023-07-13  190.539993  180.426800  169.323700         1    0.004049
# 2023-07-14  190.690002  180.869800  169.705100         1    0.000787
#
#             stratergy
# Date
# 1991-05-23        NaN
# 1991-05-24   0.016483
# 1991-05-28   0.002721
# 1991-05-29   0.021507
# ...

# %%
data.dropna(inplace = True)

# %%
data[["returnsb&h", "stratergy"]].sum()
# Out:
# returnsb&h    6.159711
# stratergy     2.197952
# dtype: float64

# %%
data[["returnsb&h", "stratergy"]].sum().apply(np.exp) # what $1 investment will be
# Out:
# returnsb&h    473.291270
# stratergy       9.006545
# dtype: float64

# %%
# annual standard deviation
data[["returnsb&h", "stratergy"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.437445
# stratergy     0.437591
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Stratergy adjusted with long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"], 1, 0)

# %%
data["stratergy2"] = data["returnsb&h"]*data.position2.shift(1)
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# 1991-06-03    0.439732    0.513259    0.515223        -1    0.046761
# ...                ...         ...         ...       ...         ...
# 2023-07-10  188.610001  179.212600  168.262200         1   -0.010915
# 2023-07-11  188.080002  179.606000  168.611000         1   -0.002814
# 2023-07-12  189.770004  180.007800  168.955400         1    0.008945
# 2023-07-13  190.539993  180.426800  169.323700         1    0.004049
# 2023-07-14  190.690002  180.869800  169.705100         1    0.000787
#
#             stratergy  position2  stratergy2
# Date
# 1991-05-28   0.002721          1    0.002721
# ...

# %%
data[["returnsb&h", "stratergy2"]].sum()
# Out:
# returnsb&h    6.143228
# stratergy2    4.162348
# dtype: float64

# %%
data[["returnsb&h", "stratergy2"]].sum().apply(np.exp)
# Out:
# returnsb&h    465.554045
# stratergy2     64.222170
# dtype: float64

# %%
# Standard deviation has been reduced, showing risk has been reduced
# Taking a long bias has given much better returns
# Therefore stratergy 2 is better than statergy 1
data[["returnsb&h", "stratergy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.437464
# stratergy2    0.338085
# dtype: float64

# %%
data[["stratergy", "stratergy2"]].std()*np.sqrt(252)
# Out:
# stratergy     0.437609
# stratergy2    0.338085
# dtype: float64

# %% [markdown]
# # Creating a function

# %%
def test_stratergy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"] = np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["stratergy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["stratergy"].sum())
    std=data["stratergy"].std()*np.sqrt(252)
                   
    return ret,std

# %%
# SMA_S calculates the 50 day moving average 
# SMA_L calculates the 200 day moving average
test_stratergy("SPY", "2000-01-01", "2023-01-01", (50, 200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (4.664151972008176, 0.19774639958570314)

# %% [markdown]
# ## Creating a class

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start, end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data = self.data2.copy().dropna()
        data["position"] = np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["stratergy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["Returns Buy&Hold"]=data["returns"].cumsum().apply(np.exp)
        data["returns stratergy"] = data["stratergy"].cumsum().apply(np.exp)
        perf=data["returns stratergy"].iloc[-1]
        outperf=perf-data["Returns Buy&Hold"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["stratergy"].sum())
        std=data["stratergy"].std()*np.sqrt(252)
                   
        # return ret,std
        return round(perf, 6), round(outperf, 6)
        
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}|\ SMA_S={} | SMA_L{}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["Returns Buy&Hold", "returns stratergy"]].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester("SPY", 50, 100, "2000-01-01", "2023-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (1.689963, -1.036811)

# %%
tester.plot_results()
